# %% [markdown]
# # Week 1 Assignment
# ### Requirements
# Start a Jupyter Notebook using any platform that you are comfortable with and do the following:
# 1. Write some markdown to explain that this notebook will be mainly used for the capstone project
# 2. Import the pandas library as pd.
# 3. Import the Numpy library as np.
# 4. Print the following the statement: Hello Capstone Project Course!

# %% [markdown]
# This notebook is used for the capstone project of the course [Applied Data Science Capstone](https://www.coursera.org/learn/applied-data-science-capstone) on [Coursera](https://www.coursera.org).

# %% [markdown]
# Import the pandas library as pd.

# %%
import pandas as pd

# %% [markdown]
# Import the Numpy library as np

# %%
import numpy as np

# %% [markdown]
# Print the statement: Hello Capstone Project Course!

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
